# %%
import nltk

# %%
from nltk.book import *

# %%
nltk.book.texts()
# Out:
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# returns the context in which the word 'monstrous' appears
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text5.concordance("hate")
# Out:
# Displaying 23 of 23 matches:
# can get . JOIN PART who is he U6 ? i hate it when my devotion to christianity
# T U7 PART there is not ! heyy U148 i hate you . boys are naughtier U92 . JOIN
# ghtier U92 . JOIN bye U148 Hmm you I hate you say .. Guess what PART i hate yo
#  I hate you say .. Guess what PART i hate you U121 fuck your ugly JOIN if i ha
# 84 . ACTION sits with U92 . hmph . i hate you U68 . does that mean I want you
# on . If I was an ex prisoner would u hate me ? wb U18 what took forever ... th
# ol smile stop doin' it then U37 Do u hate me now yeah ... U37 I put it up for
# OIN . ACTION hates no one . Sure ill hate ya if ya want me to lmao I 'm not go
# n ? damn ... U41 .... that 's cool i hate paragraphs U16 .. I 'm ok , how are
# of you tried myspace for dating .. i hate to promoter other sites .. i hate ya
#  i hate to promoter other sites .. i hate yahoo but now there is alternatives
#  play games oh but not really JOIN i hate it . its so boring .. exactly . id r
# ...

# %%
# returns other words that appear in similar context
text5.similar("hate")
# Out:
# love like want know thought see pm got talk wanted need call going
# give missed keep meant needed tried with

# %%
# shows the frequency of words from every inauguration speech 
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America", "liberty", "justice", "guns"])

# %%
# shows the frequency of words from wall street journal
text7.dispersion_plot(["finance", "economy", "recession", "interest"])

# %%
# shows the length of the text in words
len(text7)
# Out:
# 100676

# %%
# shows the number of unique words used in text1
len(set(text1))
# Out:
# 19317

# %%
# unique words used in Moby Dick (as a percentage)
len(set(text1)) / len(text1) * 100
# Out:
# 7.406285585022563

# %%
# unique words used in Sense and Sensibility (as a percentage)
len(set(text2)) / len(text2) *100
# Out:
# 4.826383002768831

# %%
# returns a section of the unique words in the text - also knows as lexical diversity
words_in_moby = sorted(set(text1))
words_in_moby[500:10000]
# Out:
# ['August',
#  'Aunt',
#  'Australia',
#  'Australian',
#  'Austrian',
#  'Author',
#  'Authors',
#  'Auto',
#  'Availing',
#  'Avast',
#  'Avatar',
#  'Aware',
#  'Away',
#  'Awful',
#  'Ay',
#  'Aye',
#  'Azores',
#  'BACK',
#  'BACKED',
#  'BACON',
#  'BALEINE',
#  'BALLENA',
#  'BANKS',
#  'BARON',
#  'BATTLE',
#  'BE',
#  'BEALE',
#  'BEFORE',
#  'BEING',
#  'BELFAST',
#  'BELOW',
#  'BENCH',
#  'BENNETT',
#  'BERMUDAS',
#  'BETWEEN',
#  'BEWARE',
#  'BIOGRAPHY',
#  'BIT',
#  'BLACK',
#  'BLACKSMITH',
#  'BLACKSTONE',
#  'BLOOD',
#  'BLOODY',
#  'BLOWS',
#  'BOARD',
#  'BOAT',
#  'BOATS',
#  'BOOK',
#  'BOOKS',
#  'BOSOM',
#  'BOTTOM',
#  'BOUTON',
#  'BRACE',
#  'BRACTON',
#  'BREACH',
#  'BREAKERS',
#  'BREAKWATER',
#  'BRIT',
#  'BROKE',
#  'BROTHER',
#  'BROWN',
#  'BROWNE',
#  'BURKE',
#  'BURST',
#  'BUSILY',
#  'BY',
#  'Babel',
#  'Babylon',
#  'Babylonian',
#  'Bachelor',
#  'Back',
#  'Backs',
#  'Bad',
#  'Baden',
#  'Bag',
#  'Balaene',
#  'Baliene',
#  'Baling',
# ...

# %%
# will return all the unique words (in PyCharm as iPython prunes)
set(text1)
# Out:
# {'bodies',
#  'phantoms',
#  'deserving',
#  'Where',
#  'rescued',
#  'Savesoul',
#  'pitiless',
#  'H',
#  'baptized',
#  'ingloriously',
#  'disjointedly',
#  'distances',
#  'aggrieved',
#  'bodied',
#  'HEIGHT',
#  'oarsmen',
#  'candles',
#  'bespeaking',
#  'securely',
#  'sports',
#  'pastures',
#  'Bridge',
#  'turtles',
#  'preeminence',
#  'Woebegone',
#  'structural',
#  'school',
#  'hay',
#  'injured',
#  'rounding',
#  'BLACK',
#  'Gate',
#  'solve',
#  'hymn',
#  'Owing',
#  'unassured',
#  'staggers',
#  'Marius',
#  'Emboldened',
#  'expanding',
#  'sorrows',
#  'tilting',
#  'reefed',
#  'wrinkled',
#  'analytic',
#  'SENTENCE',
#  'legatees',
#  'snore',
#  'Hearing',
#  'awestruck',
#  'confirmation',
#  'buy',
#  'deplore',
#  'tepid',
#  'drawbacks',
#  'Victory',
#  'Hem',
#  'chases',
#  'time',
#  'Espying',
#  'sluggish',
#  'tumbling',
#  'awful',
#  'Venetianly',
#  'wildness',
#  'reydan',
#  'Point',
#  'ANNALS',
#  'bands',
#  'rebels',
#  'carrion',
# ...
